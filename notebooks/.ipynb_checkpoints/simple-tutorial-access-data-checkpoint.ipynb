# %%
import pandas as pd

# %%
df = pd.read_csv("../data/percentage_origin_names_municipality_classified_by_secondsurname.csv")
df
# Out:
#                uf_mun_x  total     AFR     ASI     EST      FRC     GER  \
# 0         AC_ACRELANDIA  11269  0.2573  0.8608  0.0532   2.2451  0.8253
# 1       AC_ASSIS BRASIL   7465  0.1206  1.0449  0.0000   1.7950  0.2545
# 2          AC_BRASILEIA  36315  3.0180  1.8587  0.0909  18.4194  3.3512
# 3             AC_BUJARI   6946  0.2160  0.6766  0.0144   0.9070  0.4175
# 4           AC_CAPIXABA   6317  0.1900  0.9023  0.0158   0.8073  0.3324
# ...                 ...    ...     ...     ...     ...      ...     ...
# 5565  TO_TOCANTINOPOLIS  28116  0.1849  0.3414  0.0071   1.3658  0.2703
# 5566        TO_TUPIRAMA   1122  0.0000  0.5348  0.0891   1.3369  0.5348
# 5567      TO_TUPIRATINS   1562  0.1280  0.4481  0.0000   1.1524  0.2561
# 5568    TO_WANDERLANDIA   8909  0.1459  0.8867  0.0112   1.0327  0.1235
# 5569         TO_XAMBIOA  16288  0.3008  0.2824  0.0184   1.3752  0.2333
#
#          GRE      IBR     ITA     JEW     MUS     NOR     RUS
# ...
